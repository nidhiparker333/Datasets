# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhiparker333/Python/blob/main/NLP_Twitter_Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# URL of the raw CSV file on GitHub
url = 'https://raw.githubusercontent.com/nidhiparker333/Datasets/main/Amazon%20Reviews-%20Nidhi%20Parker.csv'

# Read the CSV file directly into a pandas DataFrame
df = pd.read_csv(url)

# Display the first few rows of the dataframe
df.head()
# Out:
#    rating       date         variation  \
# 0       5  31-Jul-18  Charcoal Fabric
# 1       5  31-Jul-18  Charcoal Fabric
# 2       4  31-Jul-18    Walnut Finish
# 3       5  31-Jul-18  Charcoal Fabric
# 4       5  31-Jul-18  Charcoal Fabric
#
#                                     verified_reviews  feedback
# 0                                      Love my Echo!         1
# 1                                          Loved it!         1
# 2  Sometimes while playing a game, you can answer...         1
# 3  I have had a lot of fun with this thing. My 4 ...         1
# 4                                              Music         1

# %%
# Set seaborn style to 'dark' and modify background
sns.set_theme(style="darkgrid", palette="muted")

# Customizing Matplotlib to resemble a Monokai-like theme
plt.rcParams['axes.facecolor'] = '#2e2e2e'  # Background color for the plot
plt.rcParams['axes.edgecolor'] = '#d1d1d1'  # Color of axes' edges
plt.rcParams['axes.labelcolor'] = '#f8f8f2'  # Color of axis labels
plt.rcParams['xtick.color'] = '#f8f8f2'  # X-axis tick color
plt.rcParams['ytick.color'] = '#f8f8f2'  # Y-axis tick color
plt.rcParams['text.color'] = '#f8f8f2'  # Text color for titles, labels, etc.
plt.rcParams['grid.color'] = '#444444'  # Color of the grid lines
plt.rcParams['figure.facecolor'] = '#2e2e2e'  # Background color of the figure
plt.rcParams['figure.edgecolor'] = '#444444'  # Border color of the figure
